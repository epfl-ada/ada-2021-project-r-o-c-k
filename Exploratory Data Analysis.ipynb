# %%
import pandas as pd
import numpy as np
import bz2
import json

# %%
# read the large compressed file in 1 go (may not work)
path = 'D:/ADA_quotebank/quotes-2020_preprocessed.json.bz2' #local location
df_quotes = pd.read_json(path, lines=True, compression='bz2')
df_quotes = df_quotes.set_index('qid') #Change and rename index for future merging
df_quotes.index.rename('id', inplace=True)
df_quotes.head(5)
# Out:
#                      quoteID  \
# id
# Q367796    2020-01-16-000088
# Q20684375  2020-01-24-000168
# Q5268447   2020-01-17-000357
# Q4864119   2020-04-02-000239
# Q816459    2020-03-19-000276
#
#                                                    quotation  \
# id
# Q367796    [ Department of Homeland Security ] was livid ...
# Q20684375  [ I met them ] when they just turned 4 and 7. ...
# Q5268447   [ The delay ] will have an impact [ on Slough ...
# Q4864119   [ The scheme ] treats addiction as an illness ...
# Q816459    [ These ] actions will allow households who ha...
#
#                        speaker    prob
# id
# Q367796             Sue Myrick  0.8867
# Q20684375  Meghan King Edmonds  0.5446
# Q5268447          Dexter Smith  0.9240
# Q4864119       Barry Coppinger  0.9017
# Q816459             Ben Carson  0.9227

# %%
#Load speaker attributes parquet file
df_attrib = pd.read_parquet("speaker_attributes.parquet\speaker_attributes.parquet")
df_attrib.drop(columns=['aliases','US_congress_bio_ID','type','lastrevid','candidacy','label'],inplace=True)
#df_attrib = df_attrib.set_index('id')

#Load QID correspondance file and remove description column
df_labels = pd.read_csv('wikidata_labels_descriptions_quotebank.csv.bz2', compression='bz2', index_col = 'QID')
df_labels = df_labels.drop(['Description'], axis=1)

# %%
#Merge quotes file and speaker attributes file based on the unique qid of the speaker
df = df_quotes.merge(df_attrib, left_index=True, right_index=True)
df.head(5)

# %%
def get_qid_label(df, labels):
    '''
    Replaces Wikidata Qids with the corresponding text
    :param df: dataframe to modify
    :param dflabels: 
    :return: the updated dataframe with text instead of qids
    '''
    for col in df.columns:
        try:
            df.loc[:, 'label'] = df.loc[:, col].apply(lambda x: [labels.loc[cat].item() for cat in x] if x is not None else x)     
        except:
            continue
    return df

# %%
df_out = get_qid_label(df_attrib,df_labels)

# %%
df_out.head(10)
# Out:
#                     quoteID  \
# id
# Q1000053  2020-01-30-115748
# Q1000053  2020-01-30-110614
# Q1000053  2020-02-26-086429
# Q1000053  2020-02-25-076403
# Q1000053  2020-01-09-098083
# Q1000053  2020-01-28-105408
# Q1000053  2020-02-11-012952
# Q1000053  2020-02-28-048691
# Q1000053  2020-01-30-075841
# Q1000053  2020-02-28-048692
#
#                                                   quotation          speaker  \
# id
# Q1000053  We stress that any attempts to fuel the confli...  Vasily Nebenzya
# Q1000053  We consistently send signals to abandon aggres...  Vasily Nebenzya
# Q1000053  We understand the concerns of a number of non-...  Vasily Nebenzya
# Q1000053          We cannot agree to that kind of approach,  Vasily Nebenzya
# Q1000053  violation and noncompliance of international law.  Vasily Nebenzya
# Q1000053  We were not consulted, we don't know what this...  Vasily Nebenzya
# Q1000053  But what if one side-Palestine-considers the p...  Vasily Nebenzya
# Q1000053                         not to bury Astana process  Vasily Nebenzya
# Q1000053  Russia has no hidden agenda in the Libyan conf...  Vasily Nebenzya
# Q1000053                    not to bury the Astana process.  Vasily Nebenzya
#
#             prob            date_of_birth     nationality      gender  \
# id
# Q1000053  0.9429  [+1962-02-26T00:00:00Z]  [Q159, Q15180]  [Q6581097]
# Q1000053  0.5209  [+1962-02-26T00:00:00Z]  [Q159, Q15180]  [Q6581097]
# Q1000053  0.9361  [+1962-02-26T00:00:00Z]  [Q159, Q15180]  [Q6581097]
# Q1000053  0.9680  [+1962-02-26T00:00:00Z]  [Q159, Q15180]  [Q6581097]
# Q1000053  0.9364  [+1962-02-26T00:00:00Z]  [Q159, Q15180]  [Q6581097]
# Q1000053  0.9512  [+1962-02-26T00:00:00Z]  [Q159, Q15180]  [Q6581097]
# Q1000053  0.8329  [+1962-02-26T00:00:00Z]  [Q159, Q15180]  [Q6581097]
# Q1000053  0.5201  [+1962-02-26T00:00:00Z]  [Q159, Q15180]  [Q6581097]
# Q1000053  0.8704  [+1962-02-26T00:00:00Z]  [Q159, Q15180]  [Q6581097]
# Q1000053  0.9692  [+1962-02-26T00:00:00Z]  [Q159, Q15180]  [Q6581097]
#
#          ethnic_group         occupation party academic_degree religion label
# id
# Q1000053         None  [Q193391, Q82955]  None            None     None  None
# Q1000053         None  [Q193391, Q82955]  None            None     None  None
# Q1000053         None  [Q193391, Q82955]  None            None     None  None
# Q1000053         None  [Q193391, Q82955]  None            None     None  None
# Q1000053         None  [Q193391, Q82955]  None            None     None  None
# Q1000053         None  [Q193391, Q82955]  None            None     None  None
# Q1000053         None  [Q193391, Q82955]  None            None     None  None
# Q1000053         None  [Q193391, Q82955]  None            None     None  None
# Q1000053         None  [Q193391, Q82955]  None            None     None  None
# Q1000053         None  [Q193391, Q82955]  None            None     None  None

# %%
df_attrib = df_attrib.set_index('id')
df_attrib.head(10)
# Out:
#                  date_of_birth     nationality      gender ethnic_group  \
# id
# Q23    [+1732-02-22T00:00:00Z]  [Q161885, Q30]  [Q6581097]         None
# Q42    [+1952-03-11T00:00:00Z]          [Q145]  [Q6581097]   [Q7994501]
# Q1868  [+1868-08-23T00:00:00Z]           [Q31]  [Q6581097]         None
# Q207   [+1946-07-06T00:00:00Z]           [Q30]  [Q6581097]         None
# Q297   [+1599-06-06T00:00:00Z]           [Q29]  [Q6581097]         None
# Q368   [+1915-11-25T00:00:00Z]          [Q298]  [Q6581097]         None
# Q501   [+1821-04-09T00:00:00Z]          [Q142]  [Q6581097]    [Q121842]
# Q619   [+1473-02-19T00:00:00Z]      [Q1649871]  [Q6581097]      [Q1026]
# Q633   [+1945-11-12T00:00:00Z]      [Q16, Q30]  [Q6581097]         None
# Q640   [+1969-00-00T00:00:00Z]          [Q183]  [Q6581097]         None
#
#                                               occupation      party  \
# id
# Q23    [Q82955, Q189290, Q131512, Q1734662, Q294126, ...  [Q327591]
# Q42    [Q214917, Q28389, Q6625963, Q4853732, Q1884422...       None
# Q1868  [Q36180, Q40348, Q182436, Q1265807, Q205375, Q...       None
# Q207   [Q82955, Q15982858, Q18814623, Q1028181, Q1408...   [Q29468]
# Q297                                          [Q1028181]       None
# Q368                                   [Q189290, Q82955]  [Q327591]
# Q501   [Q49757, Q4164507, Q11774202, Q333634, Q36180,...       None
# Q619   [Q11063, Q185351, Q188094, Q170790, Q16012028,...       None
# Q633   [Q177220, Q488205, Q2526255, Q639669, Q1881462...       None
# Q640                                 [Q33231, Q41546637]       None
#
#       academic_degree                    religion
# id
# Q23              None                   [Q682443]
# Q42              None                        None
# Q1868            None                        None
# Q207             None  [Q329646, Q682443, Q33203]
# Q297             None                        None
# Q368             None                     [Q1841]
# Q501             None                     [Q1841]
# Q619             None                     [Q1841]
# Q633             None                        None
# Q640             None                        None

# %%
genders = df.gender.value_counts().rename_axis('qid').reset_index(name='counts')
genders.head(5)
# Out:
#            qid   counts
# 0   [Q6581097]  1899635
# 1   [Q6581072]   563199
# 2   [Q1052281]     2721
# 3     [Q48270]     1448
# 4  [Q18116794]      895

# %%
genders_exp = genders["qid"].apply(pd.Series)

# %%
genders = get_qid_label(genders,df_labels)
genders[]
# Out:
#                                qid   counts  \
# 0                       [Q6581097]  1899635
# 1                       [Q6581072]   563199
# 2                       [Q1052281]     2721
# 3                         [Q48270]     1448
# 4                      [Q18116794]      895
# 5                       [Q2449503]      392
# 6               [Q6581072, Q48270]      175
# 7                       [Q1984232]      112
# 8               [Q48270, Q6581072]      111
# 9                      [Q12964198]      106
# 10                     [Q15145778]       73
# 11                     [Q15145779]       57
# 12           [Q15145779, Q1097630]       47
# 13               [Q48270, Q189125]       33
# 14            [Q27679766, Q859614]       23
# 15            [Q1052281, Q6581097]       17
# 16            [Q6581097, Q6581072]        8
# 17              [Q6581072, Q48270]        7
# 18            [Q6581097, Q6581072]        6
# 19            [Q6581072, Q6581097]        5
# 20            [Q6581097, Q6581072]        4
# 21            [Q6581072, Q3277905]        4
# 22           [Q6581097, Q18116794]        4
# 23            [Q6581072, Q1097630]        4
# 24           [Q18116794, Q6581097]        3
# 25                       [Q505371]        3
# 26              [Q1097630, Q48270]        3
# 27            [Q6581072, Q2449503]        3
# 28   [Q2449503, Q48270, Q12964198]        3
# 29             [Q179294, Q6581097]        3
# 30           [Q6581072, Q15145779]        3
# 31            [Q1097630, Q6581097]        3
# 32                      [Q1289754]        2
# 33            [Q6581097, Q6581072]        2
# 34            [Q6581097, Q6581072]        2
# 35                        [Q48279]        2
# 36            [Q6581097, Q1052281]        2
# 37            [Q6581097, Q1052281]        2
# 38            [Q1052281, Q6581097]        2
# 39            [Q6581072, Q1097630]        2
# 40             [Q6581072, Q301702]        2
# 41            [Q6581072, Q6581097]        1
# 42           [Q1097630, Q12964198]        1
# 43            [Q6581097, Q1097630]        1
# 44            [Q6581097, Q6581072]        1
# 45            [Q1052281, Q6581072]        1
# 46            [Q6581072, Q6581072]        1
# 47            [Q6581097, Q6581072]        1
# 48            [Q6581072, Q6581097]        1
# 49               [Q48270, Q505371]        1
# 50  [Q1097630, Q6581097, Q6581072]        1
#
#                                           label
# 0                                        [male]
# 1                                      [female]
# 2                          [transgender female]
# 3                                  [non-binary]
# 4                                 [genderfluid]
# 5                            [transgender male]
# 6                          [female, non-binary]
# 7                                     [shemale]
# 8                          [non-binary, female]
# 9                                 [genderqueer]
# 10                             [cisgender male]
# 11                           [cisgender female]
# 12                 [cisgender female, intersex]
# 13             [non-binary, transgender person]
# 14                   [transmasculine, bigender]
# 15                   [transgender female, male]
# 16                               [male, female]
# 17                         [female, non-binary]
# 18                               [male, female]
# 19                               [female, male]
# 20                               [male, female]
# 21                               [female, māhū]
# 22                          [male, genderfluid]
# 23                           [female, intersex]
# 24                          [genderfluid, male]
# 25                                    [agender]
# 26                       [intersex, non-binary]
# 27                   [female, transgender male]
# 28  [transgender male, non-binary, genderqueer]
# 29                               [eunuch, male]
# 30                   [female, cisgender female]
# 31                             [intersex, male]
# 32                                   [neutrois]
# 33                               [male, female]
# 34                               [male, female]
# 35                               [third gender]
# 36                   [male, transgender female]
# 37                   [male, transgender female]
# 38                   [transgender female, male]
# 39                           [female, intersex]
# 40                         [female, two-spirit]
# 41                               [female, male]
# 42                      [intersex, genderqueer]
# 43                             [male, intersex]
# 44                               [male, female]
# 45                 [transgender female, female]
# 46                             [female, female]
# 47                               [male, female]
# 48                               [female, male]
# 49                        [non-binary, agender]
# 50                     [intersex, male, female]

# %%
genders_exp = genders["label"].apply(pd.Series)
genders_exp
# Out:
#                      0                   1            2
# 0                 male                 NaN          NaN
# 1               female                 NaN          NaN
# 2   transgender female                 NaN          NaN
# 3           non-binary                 NaN          NaN
# 4          genderfluid                 NaN          NaN
# 5     transgender male                 NaN          NaN
# 6               female          non-binary          NaN
# 7              shemale                 NaN          NaN
# 8           non-binary              female          NaN
# 9          genderqueer                 NaN          NaN
# 10      cisgender male                 NaN          NaN
# 11    cisgender female                 NaN          NaN
# 12    cisgender female            intersex          NaN
# 13          non-binary  transgender person          NaN
# 14      transmasculine            bigender          NaN
# 15  transgender female                male          NaN
# 16                male              female          NaN
# 17              female          non-binary          NaN
# 18                male              female          NaN
# 19              female                male          NaN
# 20                male              female          NaN
# 21              female                māhū          NaN
# 22                male         genderfluid          NaN
# 23              female            intersex          NaN
# 24         genderfluid                male          NaN
# 25             agender                 NaN          NaN
# 26            intersex          non-binary          NaN
# 27              female    transgender male          NaN
# 28    transgender male          non-binary  genderqueer
# 29              eunuch                male          NaN
# 30              female    cisgender female          NaN
# 31            intersex                male          NaN
# 32            neutrois                 NaN          NaN
# 33                male              female          NaN
# 34                male              female          NaN
# 35        third gender                 NaN          NaN
# 36                male  transgender female          NaN
# 37                male  transgender female          NaN
# 38  transgender female                male          NaN
# 39              female            intersex          NaN
# 40              female          two-spirit          NaN
# 41              female                male          NaN
# 42            intersex         genderqueer          NaN
# 43                male            intersex          NaN
# 44                male              female          NaN
# 45  transgender female              female          NaN
# 46              female              female          NaN
# 47                male              female          NaN
# 48              female                male          NaN
# 49          non-binary             agender          NaN
# 50            intersex                male       female

# %%
for idx, row in genders_exp.iterrows():
    if genders_exp[1] != np.Nan or genders_exp[2] != np.Nan:
        genders['label'][idx] = 'other'
    elif genders_exp
# Out:
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6             non-binary
# 7                    NaN
# 8                 female
# 9                    NaN
# 10                   NaN
# 11                   NaN
# 12              intersex
# 13    transgender person
# 14              bigender
# 15                  male
# 16                female
# 17            non-binary
# 18                female
# 19                  male
# 20                female
# 21                  māhū
# 22           genderfluid
# 23              intersex
# 24                  male
# 25                   NaN
# 26            non-binary
# 27      transgender male
# 28            non-binary
# 29                  male
# 30      cisgender female
# 31                  male
# 32                   NaN
# 33                female
# 34                female
# 35                   NaN
# 36    transgender female
# 37    transgender female
# 38                  male
# 39              intersex
# 40            two-spirit
# 41                  male
# 42           genderqueer
# 43              intersex
# 44                female
# 45                female
# 46                female
# 47                female
# 48                  male
# 49               agender
# 50                  male
# Name: 1, dtype: object

# %%
def gender_labels(df, labels):
    '''
    Replaces Wikidata Qids with the corresponding text
    :param df: dataframe to modify
    :param dflabels: 
    :return: the updated dataframe with text instead of qids
    '''
    for col in df.columns:
        try:
            df.loc[:, 'label'] = df.loc[:, col].apply(lambda x: labels.loc[cat].item() for cat in x if x is not None else x)     
        except:
            continue
    return df

# %%
#genders.loc[genders['label'] == ['male']]
genders['qid'][2].shape[0]
#genders[['qid']].to_numpy()
# Out:
# 1

# %%
np.shape(genders['qid'].head(10)[6])[0]
# Out:
# 2

# %%
dfmid = pd.DataFrame({'QID': ['Q15991263'], 'Label': ['auctioneer']})
dfmid = dfmid.set_index('QID')
pd.concat([dflabels, dfmid])
# Out:
#                                                         Label
# QID
# Q31                                                   Belgium
# Q45                                                  Portugal
# Q75                                                  Internet
# Q148                               People's Republic of China
# Q155                                                   Brazil
# ...                                                       ...
# Q106341153                               biochemistry teacher
# Q106368830  2018 Wigan Metropolitan Borough Council electi...
# Q106369692  2018 Wigan Metropolitan Borough Council electi...
# Q106376887                                                NaN
# Q15991263                                          auctioneer
#
# [36970 rows x 1 columns]

# %%
dffinal
# Out:
#                     quoteID  \
# id
# Q1000053  2020-01-30-115748
# Q1000053  2020-01-30-110614
# Q1000053  2020-02-26-086429
# Q1000053  2020-02-25-076403
# Q1000053  2020-01-09-098083
# ...                     ...
# Q999711   2020-03-19-074326
# Q999711   2020-02-27-066900
# Q999711   2020-03-05-074250
# Q999711   2020-02-27-077480
# Q999711   2020-03-05-034322
#
#                                                   quotation  \
# id
# Q1000053  We stress that any attempts to fuel the confli...
# Q1000053  We consistently send signals to abandon aggres...
# Q1000053  We understand the concerns of a number of non-...
# Q1000053          We cannot agree to that kind of approach,
# Q1000053  violation and noncompliance of international law.
# ...                                                     ...
# Q999711   This is his home racetrack and that also makes...
# Q999711   The Hanover Bentinck and Brant Agricultural So...
# Q999711   This is a very unique opportunity for me. My f...
# Q999711   This is a very unique opportunity for me. My f...
# Q999711   I'm very grateful to the agricultural society ...
#
#                     speaker    prob aliases            date_of_birth  \
# id
# Q1000053    Vasily Nebenzya  0.9429    None  [+1962-02-26T00:00:00Z]
# Q1000053    Vasily Nebenzya  0.5209    None  [+1962-02-26T00:00:00Z]
# Q1000053    Vasily Nebenzya  0.9361    None  [+1962-02-26T00:00:00Z]
# Q1000053    Vasily Nebenzya  0.9680    None  [+1962-02-26T00:00:00Z]
# Q1000053    Vasily Nebenzya  0.9364    None  [+1962-02-26T00:00:00Z]
# ...                     ...     ...     ...                      ...
# Q999711   Steve Fitzsimmons  0.7526    None  [+1976-09-07T00:00:00Z]
# Q999711   Steve Fitzsimmons  0.5578    None  [+1976-09-07T00:00:00Z]
# Q999711   Steve Fitzsimmons  0.7475    None  [+1976-09-07T00:00:00Z]
# Q999711   Steve Fitzsimmons  0.6221    None  [+1976-09-07T00:00:00Z]
# Q999711   Steve Fitzsimmons  0.7473    None  [+1976-09-07T00:00:00Z]
#
#                      nationality  gender   lastrevid ethnic_group  \
# id
# Q1000053  [Russia, Soviet Union]  [male]  1391394799         None
# Q1000053  [Russia, Soviet Union]  [male]  1391394799         None
# Q1000053  [Russia, Soviet Union]  [male]  1391394799         None
# Q1000053  [Russia, Soviet Union]  [male]  1391394799         None
# Q1000053  [Russia, Soviet Union]  [male]  1391394799         None
# ...                          ...     ...         ...          ...
# Q999711              [Australia]  [male]  1313714618         None
# Q999711              [Australia]  [male]  1313714618         None
# Q999711              [Australia]  [male]  1313714618         None
# Q999711              [Australia]  [male]  1313714618         None
# Q999711              [Australia]  [male]  1313714618         None
#
#          US_congress_bio_ID         occupation party academic_degree  \
# id
# Q1000053               None  [Q193391, Q82955]  None            None
# Q1000053               None  [Q193391, Q82955]  None            None
# Q1000053               None  [Q193391, Q82955]  None            None
# Q1000053               None  [Q193391, Q82955]  None            None
# Q1000053               None  [Q193391, Q82955]  None            None
# ...                     ...                ...   ...             ...
# Q999711                None          [Q937857]  None            None
# Q999711                None          [Q937857]  None            None
# Q999711                None          [Q937857]  None            None
# Q999711                None          [Q937857]  None            None
# Q999711                None          [Q937857]  None            None
#
#                       label candidacy  type religion
# id
# Q1000053    Vasily Nebenzya      None  item     None
# Q1000053    Vasily Nebenzya      None  item     None
# Q1000053    Vasily Nebenzya      None  item     None
# Q1000053    Vasily Nebenzya      None  item     None
# Q1000053    Vasily Nebenzya      None  item     None
# ...                     ...       ...   ...      ...
# Q999711   Steve Fitzsimmons      None  item     None
# Q999711   Steve Fitzsimmons      None  item     None
# Q999711   Steve Fitzsimmons      None  item     None
# Q999711   Steve Fitzsimmons      None  item     None
# Q999711   Steve Fitzsimmons      None  item     None
#
# [2498965 rows x 18 columns]

# %%
for item in dffinal['gender']:
    if item is not None:
        item = item[0]
    else:
        item=item

# %%
dffinal
# Out:
#                     quoteID  \
# id
# Q1000053  2020-01-30-115748
# Q1000053  2020-01-30-110614
# Q1000053  2020-02-26-086429
# Q1000053  2020-02-25-076403
# Q1000053  2020-01-09-098083
# ...                     ...
# Q999711   2020-03-19-074326
# Q999711   2020-02-27-066900
# Q999711   2020-03-05-074250
# Q999711   2020-02-27-077480
# Q999711   2020-03-05-034322
#
#                                                   quotation  \
# id
# Q1000053  We stress that any attempts to fuel the confli...
# Q1000053  We consistently send signals to abandon aggres...
# Q1000053  We understand the concerns of a number of non-...
# Q1000053          We cannot agree to that kind of approach,
# Q1000053  violation and noncompliance of international law.
# ...                                                     ...
# Q999711   This is his home racetrack and that also makes...
# Q999711   The Hanover Bentinck and Brant Agricultural So...
# Q999711   This is a very unique opportunity for me. My f...
# Q999711   This is a very unique opportunity for me. My f...
# Q999711   I'm very grateful to the agricultural society ...
#
#                     speaker    prob aliases            date_of_birth  \
# id
# Q1000053    Vasily Nebenzya  0.9429    None  [+1962-02-26T00:00:00Z]
# Q1000053    Vasily Nebenzya  0.5209    None  [+1962-02-26T00:00:00Z]
# Q1000053    Vasily Nebenzya  0.9361    None  [+1962-02-26T00:00:00Z]
# Q1000053    Vasily Nebenzya  0.9680    None  [+1962-02-26T00:00:00Z]
# Q1000053    Vasily Nebenzya  0.9364    None  [+1962-02-26T00:00:00Z]
# ...                     ...     ...     ...                      ...
# Q999711   Steve Fitzsimmons  0.7526    None  [+1976-09-07T00:00:00Z]
# Q999711   Steve Fitzsimmons  0.5578    None  [+1976-09-07T00:00:00Z]
# Q999711   Steve Fitzsimmons  0.7475    None  [+1976-09-07T00:00:00Z]
# Q999711   Steve Fitzsimmons  0.6221    None  [+1976-09-07T00:00:00Z]
# Q999711   Steve Fitzsimmons  0.7473    None  [+1976-09-07T00:00:00Z]
#
#                      nationality  gender   lastrevid ethnic_group  \
# id
# Q1000053  [Russia, Soviet Union]  [male]  1391394799         None
# Q1000053  [Russia, Soviet Union]  [male]  1391394799         None
# Q1000053  [Russia, Soviet Union]  [male]  1391394799         None
# Q1000053  [Russia, Soviet Union]  [male]  1391394799         None
# Q1000053  [Russia, Soviet Union]  [male]  1391394799         None
# ...                          ...     ...         ...          ...
# Q999711              [Australia]  [male]  1313714618         None
# Q999711              [Australia]  [male]  1313714618         None
# Q999711              [Australia]  [male]  1313714618         None
# Q999711              [Australia]  [male]  1313714618         None
# Q999711              [Australia]  [male]  1313714618         None
#
#          US_congress_bio_ID         occupation party academic_degree  \
# id
# Q1000053               None  [Q193391, Q82955]  None            None
# Q1000053               None  [Q193391, Q82955]  None            None
# Q1000053               None  [Q193391, Q82955]  None            None
# Q1000053               None  [Q193391, Q82955]  None            None
# Q1000053               None  [Q193391, Q82955]  None            None
# ...                     ...                ...   ...             ...
# Q999711                None          [Q937857]  None            None
# Q999711                None          [Q937857]  None            None
# Q999711                None          [Q937857]  None            None
# Q999711                None          [Q937857]  None            None
# Q999711                None          [Q937857]  None            None
#
#                       label candidacy  type religion
# id
# Q1000053    Vasily Nebenzya      None  item     None
# Q1000053    Vasily Nebenzya      None  item     None
# Q1000053    Vasily Nebenzya      None  item     None
# Q1000053    Vasily Nebenzya      None  item     None
# Q1000053    Vasily Nebenzya      None  item     None
# ...                     ...       ...   ...      ...
# Q999711   Steve Fitzsimmons      None  item     None
# Q999711   Steve Fitzsimmons      None  item     None
# Q999711   Steve Fitzsimmons      None  item     None
# Q999711   Steve Fitzsimmons      None  item     None
# Q999711   Steve Fitzsimmons      None  item     None
#
# [2498965 rows x 18 columns]

# %%
dffinal.gender.value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [male]                                         1899635
# [female]                                        563199
# [transgender female]                              2721
# [non-binary]                                      1448
# [genderfluid]                                      895
# [transgender male]                                 392
# [female, non-binary]                               182
# [shemale]                                          112
# [non-binary, female]                               111
# [genderqueer]                                      106
# [cisgender male]                                    73
# [cisgender female]                                  57
# [cisgender female, intersex]                        47
# [non-binary, transgender person]                    33
# [male, female]                                      24
# [transmasculine, bigender]                          23
# [transgender female, male]                          19
# [female, male]                                       7
# [female, intersex]                                   6
# [male, transgender female]                           4
# [female, māhū]                                       4
# [male, genderfluid]                                  4
# [genderfluid, male]                                  3
# [female, cisgender female]                           3
# [intersex, male]                                     3
# [eunuch, male]                                       3
# [intersex, non-binary]                               3
# [transgender male, non-binary, genderqueer]          3
# [female, transgender male]                           3
# [agender]                                            3
# [female, two-spirit]                                 2
# [third gender]                                       2
# [neutrois]                                           2
# [female, female]                                     1
# [non-binary, agender]                                1
# [transgender female, female]                         1
# [male, intersex]                                     1
# [intersex, genderqueer]                              1
# [intersex, male, female]                             1
# Name: gender, dtype: int64

# %%
dffinal['nationality'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [United States of America]             1066919
# [United Kingdom]                        248436
# [India]                                 125727
# [Canada]                                103010
# [Australia]                              99489
#                                         ...
# [Austria, Tunisia]                           1
# [Kingdom of the Netherlands, Aruba]          1
# [France, Hungary]                            1
# [São Tomé and Príncipe]                      1
# [Norway, Malaysia, Canada]                   1
# Name: nationality, Length: 1662, dtype: int64

# %%
dfmerged.loc[:, 'occupation'] = dfmerged.loc[:, 'occupation'].apply(lambda x: [dflabels.loc[nat].item() for nat in x] if x is not None else x)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Q15991263'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14328/1168583601.py in <module>
# ----> 1 dfmerged.loc[:, 'occupation'] = dfmerged.loc[:, 'occupation'].apply(lambda x: [dflabels.loc[nat].item() for nat in x] if x is not None else x)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1097                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1098                 # "Callable[[Any], Any]"
# -> 1099                 mapped = lib.map_infer(
#    1100                     values,
#    1101                     f,  # type: ignore[arg-type]
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Local\Temp/ipykernel_14328/1168583601.py in <lambda>(x)
# ----> 1 dfmerged.loc[:, 'occupation'] = dfmerged.loc[:, 'occupation'].apply(lambda x: [dflabels.loc[nat].item() for nat in x] if x is not None else x)
#
# ~\AppData\Local\Temp/ipykernel_14328/1168583601.py in <listcomp>(.0)
# ----> 1 dfmerged.loc[:, 'occupation'] = dfmerged.loc[:, 'occupation'].apply(lambda x: [dflabels.loc[nat].item() for nat in x] if x is not None else x)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1162         # fall thru to straight lookup
#    1163         self._validate_key(key, axis)
# -> 1164         return self._get_label(key, axis=axis)
#    1165
#    1166     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1111     def _get_label(self, label, axis: int):
#    1112         # GH#5667 this will fail if the label is not present in the axis.
# -> 1113         return self.obj.xs(label, axis=axis)
#    1114
#    1115     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3774                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3775         else:
# -> 3776             loc = index.get_loc(key)
#    3777
#    3778             if isinstance(loc, np.ndarray):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Q15991263'
