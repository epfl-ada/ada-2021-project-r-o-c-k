# %%
import pandas as pd

# %%
df = pd.read_json("quotes-2019-nytimes.json", lines = True) # change to correct file path

# %%
sample_df = df[['quoteID', 'quotation']].head(50) # only for quick testing

# %%
# creating dictonary that maps each pronoun to the correct category
pronouns = {
    'me' :'self',
    'myself' : 'self',
    'ours' : 'union',
    'ourselves' : 'union',
    'us' : 'union',
    'hers' : 'other',
    'herself' : 'other',
    'him' : 'other',
    'himself' : 'other',
    'hisself' : 'other',
    'one' : 'other',
    'oneself' : 'other',
    'she' : 'other',
    'thee' : 'other',
    'theirs' : 'other',
    'them' : 'other',
    'themselves' : 'other',
    'they' : 'other',
    'thou' : 'other',
    'thy' : 'other',
    'mine' : 'self',
    'my' : 'self',
    'our' : 'union',
    'ours' : 'union',
    'her' : 'other',
    'his' : 'other',
    'their' : 'other',
    'they' : 'other', 
    'your' : 'other',
    'we' : 'union',
    'i': 'self',
    'he': 'other',
    'she': 'other',
    'you': 'other'
}

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

def add_sentiment_cols(row):
    '''
    Adds the sentiment column to the row.
    This column is based on NLTK's polarity score
    -1 one means 100 % negative, 1 100 % positive
    :param row: dataframe row to add column to
    :return: row with specified column added
    '''
    sentiments = sid.polarity_scores(row['quotation'])
    row['sentiment'] = sentiments['pos'] - sentiments['neg']
    return row

def add_morphological_cols(row):
    '''
    Adds the following columns to each row:

    self: count of pronouns referring to the speaker (ex: me, I)
    union: count of pronouns referring to the speaker and its group (ex: we, our)
    other: count of pronouns referring to someone else than the speaker (ex: he, their)
    adj_count: count of adjectives in the quote
    adj_ratio: ratio of regular adjectives in comparison to superlatives and comparatives

    -1 means only comparatives and superlatives, 1 only regular adjectives
    :param row: dataframe row to add columns to
    :return: row with specified columns added
    '''
    word_tag_pairs = nltk.pos_tag(nltk.word_tokenize(row['quotation']))
    adj_count = 0
    regular_adj_count = 0
    # Count necessary tags in the quote of the row
    for word, tag in word_tag_pairs:
        if tag == 'PRP' or tag == 'PRPS':
            if word[:2].lower() != 'it': 
                row[pronouns[word.lower()]] += 1
        elif tag[:2] == 'JJ':
            adj_count += 1
            if tag == 'JJ':
                regular_adj_count += 1
    row['adj_count'] = adj_count
    if adj_count == 0:
        row['adj_ratio'] = 0
    else:
        row['adj_ratio'] = 2 * ((regular_adj_count / adj_count) - (1 / 2))

    return row

def create_dataframe_with_features(df):
    '''
    Adds the following features to the dataframe:
    
    self: count of pronouns referring to the speaker (ex: I, my)
    union: count of pronouns referring to the speaker and its group (ex: we, our)
    other: count of pronouns referring to someone else than the speaker (ex: he, her)
    adj_count: count of adjectives in the quote
    adj_ratio: ratio of regular adjectives in comparison to superlatives and comparatives
    -1 means only comparatives and superlatives, 1 only regular adjectives
    sentiment: based on NLTK's polarity score, -1 one means 100 % negative, 1 100 % positive
    
    :param row: dataframe row to add columns to
    :return: row with specified columns added
    :param df: dataframe to add features to
    :return new_df: new dataframe with added features
    '''
    int_cols = ['self', 'union', 'other', 'adj_count']
    float_cols = ['adj_ratio', 'sentiment']
    new_df = df.copy()

    for col in int_cols:
        new_df[col] = 0

    new_df = new_df.apply(add_morphological_cols, axis = 1)
    new_df = new_df.apply(add_sentiment_cols, axis = 1)

    # making the size of the dataframe smaller by setting integers with clear upperbount to unsigned int8
    for col in float_cols:
        new_df[col] = new_df[col].astype('float16')
    for col in int_cols:
        new_df[col] = new_df[col].astype('int8')

    return new_df

# %%
new_df = create_dataframe_with_features(sample_df)
new_df
# Out:
#               quoteID                                          quotation  \
# 0   2019-04-17-024782                It is not a low-income immigration,
# 1   2019-04-02-001128  a champion figure skater switching to roller s...
# 2   2019-05-09-055187  It makes it much more difficult for him to mak...
# 3   2019-10-31-056366                       It puts me in a predicament,
# 4   2019-01-04-001792                                  A Pile of Leaves.
# 5   2019-08-15-002017                     A Senator we can call our own.
# 6   2019-02-12-002452                    a thorn in the side of cabinet,
# 7   2019-01-28-048557                             It was just on a lark,
# 8   2019-07-22-032883     It's a success, a relief and a technical feat,
# 9   2019-12-31-002666  always appreciates and respects the work and a...
# 10  2019-01-13-028337  It's crazy. I can't even really explain it rig...
# 11  2019-11-14-057913  It's critical for our country that the governm...
# 12  2019-06-19-008685  As soon as the gumballs hit or don't hit Luke ...
# 13  2019-10-02-063708  I've lived long enough, being born in 1961, th...
# 14  2019-08-08-054057     I've never been on a show that's so immediate,
# 15  2019-02-15-009152  Asylum seekers in Mexico face a heightened ris...
# 16  2019-10-26-028940  I've never seen the base more energized than i...
# 17  2019-03-20-010306   because it's dangerous to walk! Down the street!
# 18  2019-02-16-005422  Betty was succinct and to the point and had a ...
# 19  2019-10-09-061440  Like most longtime Democratic politicians, Bid...
# 20  2019-03-31-006363  but it didn't seem like this worldwide big to-do.
# 21  2019-10-20-006008  But they have taken a heck of a long time to g...
# 22  2019-02-07-014948  By the end of the game I was singing all the s...
# 23  2019-06-21-013248  Can I get in trouble? Just thought they were g...
# 24  2019-03-30-007345                    Can you give me a second, Sean?
# 25  2019-05-22-015799  Charline always impressed me by the way she wo...
# 26  2019-11-20-065087  Mr. Giuliani's requests were a `quid pro quo' ...
# 27  2019-11-18-013623  Combating housing discrimination is at the for...
# 28  2019-12-21-006596  continues to believe that the now deleted prov...
# 29  2019-01-15-064058  Never be cool. Never try to be cool. Never wor...
# 30  2019-08-20-016560  Even if the Americans sanction us, at least we...
# 31  2019-10-16-020602  Every stop he has made throughout his manageri...
# 32  2019-10-04-019252  Everyone knows what conditions of work we gave...
# 33  2019-03-12-017316  Everything that Mr. Rosen stated is exactly tr...
# 34  2019-03-19-019924  far more efficient than trucks, vans, larger g...
# 35  2019-02-20-023137                      five times in a week in 1967,
# 36  2019-08-29-020663  For me, I just try to take it as another match...
# 37  2019-08-30-020386  From there, we bounced around until I was 6 an...
# 38  2019-09-24-069091  prejudice, the ignorance, the bigotry as well ...
# 39  2019-03-08-024406                gritty, funky, but in strict tempo,
# 40  2019-09-19-073842  Probably will not endorse any candidate for pr...
# 41  2019-10-28-064521  request to investigate Biden and his son had n...
# 42  2019-05-02-026765  he has sustained a writing style that remains ...
# 43  2019-04-11-082190    sensitive to the privacy concerns of its users.
# 44  2019-09-08-037786                      She is a beast, she's brutal,
# 45  2019-04-26-048909                              She stole from banks,
# 46  2019-11-07-028754           He's been a partisan from the beginning.
# 47  2019-05-08-080720  Sir, please help me get back home! Please help...
# 48  2019-10-16-082509  So, look, I think we ought to get out of the M...
# 49  2019-10-19-039898  some of the most powerful and most eloquent re...
#
#     self  union  other  adj_count  adj_ratio  sentiment
# 0      0      0      0          1   1.000000   0.000000
# 1      0      0      0          0   0.000000   0.394043
# 2      0      0      1          1   1.000000  -0.188965
# 3      1      0      0          0   0.000000   0.000000
# 4      0      0      0          0   0.000000   0.000000
# 5      0      1      0          1   1.000000   0.000000
# 6      0      0      0          0   0.000000   0.000000
# 7      0      0      0          0   0.000000   0.000000
# 8      0      0      0          1   1.000000   0.629883
# 9      0      0      0          0   0.000000   0.482910
# 10     1      0      0          1   1.000000  -0.230957
# 11     0      0      0          4   1.000000   0.036987
# 12     0      0      0          0   0.000000   0.000000
# 13     1      0      0          2   1.000000   0.000000
# 14     1      0      0          1   1.000000   0.000000
# 15     0      0      0          3   1.000000  -0.496094
# 16     1      0      0          1   1.000000   0.263916
# 17     0      0      0          1   1.000000  -0.344971
# 18     0      0      0          3   1.000000   0.181030
# 19     0      0      0          8   0.750000   0.098022
# 20     0      0      0          2   1.000000  -0.250000
# 21     0      0      1          1   1.000000   0.000000
# 22     1      0      0          0   0.000000   0.000000
# 23     1      0      1          1   1.000000   0.152954
# 24     1      0      1          1   1.000000   0.000000
# 25     1      0      1          1   1.000000  -0.171021
# 26     0      0      0          2   1.000000   0.000000
# 27     0      0      0          0   0.000000   0.000000
# 28     0      0      0          3   1.000000   0.065002
# 29     0      0      2          7   1.000000  -0.119019
# 30     0      2      0          1  -1.000000   0.000000
# 31     0      0      2          1   1.000000   0.125977
# 32     0      1      2          0   0.000000   0.149048
# 33     1      0      0          3   0.333252   0.140991
# 34     0      0      0          2   0.000000   0.218994
# 35     0      0      0          0   0.000000   0.000000
# 36     7      0      0          2   1.000000   0.054993
# 37     3      2      0          2   1.000000   0.172974
# 38     0      0      0          0   0.000000  -0.177979
# 39     0      0      0          1   1.000000  -0.193970
# 40     0      0      0          0   0.000000  -0.218994
# 41     0      0      0          2   1.000000   0.073975
# 42     0      0      2          1   1.000000   0.000000
# 43     0      0      0          1   1.000000   0.000000
# 44     0      0      2          1   1.000000  -0.505859
# 45     0      0      1          0   0.000000   0.000000
# 46     0      0      1          0   0.000000   0.000000
# 47     2      0      0          0   0.000000   0.540039
# 48     1      1      0          0   0.000000   0.000000
# 49     0      0      0          3   0.333252   0.218994

# %% [markdown]
# # Getting speakers info (Raph)

# %%
import numpy as np
import pandas as pd
import bz2
import json

# %%
with bz2.open('./quotes-2019-nytimes.json.bz2', "rt") as bzinput:
    lines = []
    for i, line in enumerate(bzinput):
        if i == 50: break
        tweets = json.loads(line)
        lines.append(tweets)

# %%
dfquotes = pd.DataFrame(lines)

# %%
#Remove quotes without know speaker
dfquotes = dfquotes[dfquotes.speaker != 'None']

# Find speakers with one unique id
dfquotes = dfquotes[dfquotes.qids.apply(lambda x: len(x)) == 1]

# List to string the qids column
dfquotes['qids'] = dfquotes['qids'].apply(lambda x: x[0])

#Change and rename index for future merging
dfquotes = dfquotes.set_index('qids')
dfquotes.index.rename('id', inplace=True)

# %%
#Load speaker attributes parquet file
dfattrib = pd.read_parquet("speaker_attributes.parquet\speaker_attributes.parquet")

# %%
#Load QID correspondance file and remove description column
dflabels = pd.read_csv('wikidata_labels_descriptions_quotebank.csv.bz2', compression='bz2', index_col = 'QID')
dflabels = dflabels.drop(['Description'], axis=1)

# %%
#Merge quotes file and speaker attributes file based on the unique qid of the speaker
dfmerged_new = dfquotes.merge(dfattrib.set_index('id'), left_index=True, right_index=True)

# %%
for col in dfmerged_new.columns:
    try:
        dfmerged_new.loc[:, col] = dfmerged_new.loc[:, col].apply(lambda x: [dflabels.loc[nat].item() for nat in x] if x is not None else x)
    except:
        continue

# %%
dfmerged_new = dfmerged_new.drop(['numOccurrences', 'urls', 'probas', 'phase'], axis=1)

# %%
dfmerged_new
# Out:
#                      quoteID  \
# id
# Q105756    2019-04-02-001128
# Q1855840   2019-10-31-056366
# Q7817334   2019-08-15-002017
# Q3074013   2019-07-22-032883
# Q7812406   2019-01-13-028337
# Q977546    2019-06-19-008685
# Q50049     2019-10-02-063708
# Q22686     2019-02-15-009152
# Q7154794   2019-10-26-028940
# Q57552119  2019-03-31-006363
# Q2106099   2019-02-07-014948
# Q57689     2019-03-30-007345
# Q5585845   2019-11-20-065087
# Q4912529   2019-10-16-020602
# Q21933608  2019-03-12-017316
# Q27537235  2019-08-29-020663
# Q7520267   2019-08-30-020386
# Q39259     2019-09-24-069091
# Q4496      2019-09-19-073842
# Q509946    2019-05-02-026765
# Q7172014   2019-11-07-028754
# Q434706    2019-10-16-082509
#
#                                                    quotation  \
# id
# Q105756    a champion figure skater switching to roller s...
# Q1855840                        It puts me in a predicament,
# Q7817334                      A Senator we can call our own.
# Q3074013      It's a success, a relief and a technical feat,
# Q7812406   It's crazy. I can't even really explain it rig...
# Q977546    As soon as the gumballs hit or don't hit Luke ...
# Q50049     I've lived long enough, being born in 1961, th...
# Q22686     Asylum seekers in Mexico face a heightened ris...
# Q7154794   I've never seen the base more energized than i...
# Q57552119  but it didn't seem like this worldwide big to-do.
# Q2106099   By the end of the game I was singing all the s...
# Q57689                       Can you give me a second, Sean?
# Q5585845   Mr. Giuliani's requests were a `quid pro quo' ...
# Q4912529   Every stop he has made throughout his manageri...
# Q21933608  Everything that Mr. Rosen stated is exactly tr...
# Q27537235  For me, I just try to take it as another match...
# Q7520267   From there, we bounced around until I was 6 an...
# Q39259     prejudice, the ignorance, the bigotry as well ...
# Q4496      Probably will not endorse any candidate for pr...
# Q509946    he has sustained a writing style that remains ...
# Q7172014            He's been a partisan from the beginning.
# Q434706    So, look, I think we ought to get out of the M...
#
#                           speaker                 date  \
# id
# Q105756               John Updike  2019-04-02 14:58:33
# Q1855840           Xavier Becerra  2019-10-31 16:45:15
# Q7817334                 Tom Rath  2019-08-15 22:36:33
# Q3074013           Florence Parly  2019-07-22 02:37:50
# Q7812406           Todd Gurley II  2019-01-13 15:55:44
# Q977546              Errol Morris  2019-06-19 15:25:07
# Q50049             Catherine Opie  2019-10-02 21:42:56
# Q22686     President Donald Trump  2019-02-15 03:20:00
# Q7154794              Paula White  2019-10-26 20:51:55
# Q57552119              Steve Gold  2019-03-31 15:40:51
# Q2106099             Karl Paranya  2019-02-07 10:00:01
# Q57689          Martin McGuinness  2019-03-30 14:54:42
# Q5585845          Gordon Sondland  2019-11-20 00:00:00
# Q4912529             Billy Eppler  2019-10-16 16:36:51
# Q21933608          William Singer  2019-03-12 20:59:53
# Q27537235            Caty McNally  2019-08-29 05:46:46
# Q7520267             Simone Biles  2019-08-30 16:15:03
# Q39259       Recep Tayyip Erdogan  2019-09-24 20:33:32
# Q4496                 Mitt Romney  2019-09-19 09:00:12
# Q509946              Janet Maslin  2019-05-02 19:18:53
# Q7172014             Pete Hegseth  2019-11-07 04:15:25
# Q434706          Elizabeth Warren  2019-10-16 02:21:09
#
#                                                      aliases  \
# id
# Q105756                                  [John Hoyer Updike]
# Q1855840                                                None
# Q7817334                                                None
# Q3074013                       [Florence Marie Jeanne Parly]
# Q7812406                                    [Todd Gurley II]
# Q977546                                                 None
# Q50049                                                  None
# Q22686     [Donald John Trump, Donald J. Trump, Trump, Th...
# Q7154794   [Paula Michelle Furr, Paula Michelle White-Cai...
# Q57552119                                               None
# Q2106099                                                None
# Q57689     [John Martin McGuinness, Máirtín Mag Aonghusa,...
# Q5585845         [Gordon D. Sondland, Gordon David Sondland]
# Q4912529                                                None
# Q21933608                                               None
# Q27537235                                [Catherine McNally]
# Q7520267                              [Simone Arianne Biles]
# Q39259     [Recep Tayyip Erdogan, Tayyip Erdoğan, Tayyip ...
# Q4496                  [Willard Mitt Romney, Pierre Delecto]
# Q509946                                                 None
# Q7172014                                                None
# Q434706    [Elizabeth Ann Warren, Senator Warren, Elisabe...
#
#                      date_of_birth                         nationality  \
# id
# Q105756    [+1932-03-18T00:00:00Z]          [United States of America]
# Q1855840   [+1958-01-26T00:00:00Z]          [United States of America]
# Q7817334   [+1975-00-00T00:00:00Z]          [United States of America]
# Q3074013   [+1963-05-08T00:00:00Z]                            [France]
# Q7812406   [+1994-08-03T00:00:00Z]          [United States of America]
# Q977546    [+1948-02-05T00:00:00Z]          [United States of America]
# Q50049     [+1961-04-14T00:00:00Z]          [United States of America]
# Q22686     [+1946-06-14T00:00:00Z]          [United States of America]
# Q7154794   [+1966-04-20T00:00:00Z]          [United States of America]
# Q57552119  [+1985-03-01T00:00:00Z]          [United States of America]
# Q2106099   [+1975-06-27T00:00:00Z]          [United States of America]
# Q57689     [+1950-05-23T00:00:00Z]                           [Ireland]
# Q5585845   [+1957-07-16T00:00:00Z]          [United States of America]
# Q4912529   [+1975-09-16T00:00:00Z]          [United States of America]
# Q21933608                     None                                None
# Q27537235  [+2001-11-20T00:00:00Z]          [United States of America]
# Q7520267   [+1998-04-24T00:00:00Z]  [United States of America, Belize]
# Q39259     [+1954-02-26T00:00:00Z]                            [Turkey]
# Q4496      [+1947-03-12T00:00:00Z]          [United States of America]
# Q509946    [+1949-08-12T00:00:00Z]          [United States of America]
# Q7172014   [+1980-06-06T00:00:00Z]          [United States of America]
# Q434706    [+1949-06-22T00:00:00Z]          [United States of America]
#
#              gender   lastrevid         ethnic_group US_congress_bio_ID  \
# id
# Q105756      [male]  1386702708                 None               None
# Q1855840     [male]  1393554580                 None            B000287
# Q7817334     [male]  1387887635                 None               None
# Q3074013   [female]  1388274070                 None               None
# Q7812406     [male]  1368251541  [African Americans]               None
# Q977546      [male]  1391704920                 None               None
# Q50049     [female]  1395549466    [White Americans]               None
# Q22686       [male]  1395141850                 None               None
# Q7154794   [female]  1378795903                 None               None
# Q57552119    [male]  1346415165                 None               None
# Q2106099     [male]  1313995362                 None               None
# Q57689       [male]  1389262931                 None               None
# Q5585845     [male]  1377719947                 None               None
# Q4912529     [male]  1315011933                 None               None
# Q21933608    [male]  1393961996                 None               None
# Q27537235  [female]  1383460668                 None               None
# Q7520267   [female]  1388659999  [African Americans]               None
# Q39259       [male]  1393664067              [Turks]               None
# Q4496        [male]  1393565531                 None            R000615
# Q509946    [female]  1352570205                 None               None
# Q7172014     [male]  1392978915                 None               None
# Q434706    [female]  1394365746    [White Americans]            W000817
#
#                                                   occupation  \
# id
# Q105756    [poet, writer, novelist, essayist, playwright,...
# Q1855840                                [politician, lawyer]
# Q7817334                                            [writer]
# Q3074013                                        [politician]
# Q7812406                          [American football player]
# Q977546    [film director, screenwriter, non-fiction writ...
# Q50049     [artist, photographer, university teacher, aca...
# Q22686     [business magnate, investor, restaurateur, non...
# Q7154794                     [writer, televangelist, pastor]
# Q57552119  [real estate broker, reality television partic...
# Q2106099                              [athletics competitor]
# Q57689                                          [politician]
# Q5585845                          [businessperson, diplomat]
# Q4912529                                   [baseball player]
# Q21933608                                       [politician]
# Q27537235                                    [tennis player]
# Q7520267                                  [artistic gymnast]
# Q39259                            [statesperson, politician]
# Q4496      [politician, consultant, businessperson, non-f...
# Q509946    [journalist, literary critic, music critic, fi...
# Q7172014                                        [politician]
# Q434706    [jurist, politician, teacher, university teach...
#
#                                                        party  \
# id
# Q105756                                                 None
# Q1855840                                  [Democratic Party]
# Q7817334                                                None
# Q3074013                                   [Socialist Party]
# Q7812406                                                None
# Q977546                                                 None
# Q50049                                                  None
# Q22686     [Republican Party, Independence Party of Ameri...
# Q7154794                                                None
# Q57552119                                               None
# Q2106099                                                None
# Q57689                                           [Sinn Féin]
# Q5585845                                  [Republican Party]
# Q4912529                                                None
# Q21933608                                               None
# Q27537235                                               None
# Q7520267                                                None
# Q39259     [National Salvation Party, Welfare Party, Virt...
# Q4496                                     [Republican Party]
# Q509946                                                 None
# Q7172014                                  [Republican Party]
# Q434706                                   [Democratic Party]
#
#                                              academic_degree  \
# id
# Q105756                                                 None
# Q1855840                                                None
# Q7817334                                                None
# Q3074013                                                None
# Q7812406                                                None
# Q977546                                                 None
# Q50049                                                  None
# Q22686                                 [Bachelor of Science]
# Q7154794                                                None
# Q57552119                                               None
# Q2106099                                                None
# Q57689                                                  None
# Q5585845                                                None
# Q4912529                                                None
# Q21933608                                               None
# Q27537235                                               None
# Q7520267                                                None
# Q39259                                                  None
# Q4496      [Bachelor of Arts, Master of Business Administ...
# Q509946                                                 None
# Q7172014                                                None
# Q434706                    [bachelor's degree, Juris Doctor]
#
#                           label  \
# id
# Q105756             John Updike
# Q1855840         Xavier Becerra
# Q7817334               Tom Rath
# Q3074013         Florence Parly
# Q7812406            Todd Gurley
# Q977546            Errol Morris
# Q50049           Catherine Opie
# Q22686             Donald Trump
# Q7154794       Paula White-Cain
# Q57552119            Steve Gold
# Q2106099           Karl Paranya
# Q57689        Martin McGuinness
# Q5585845        Gordon Sondland
# Q4912529           Billy Eppler
# Q21933608        William Singer
# Q27537235          Caty McNally
# Q7520267           Simone Biles
# Q39259     Recep Tayyip Erdoğan
# Q4496               Mitt Romney
# Q509946            Janet Maslin
# Q7172014           Pete Hegseth
# Q434706        Elizabeth Warren
#
#                                                    candidacy  type  \
# id
# Q105756                                                 None  item
# Q1855840                                                None  item
# Q7817334                                                None  item
# Q3074013                                                None  item
# Q7812406                                                None  item
# Q977546                                                 None  item
# Q50049                                                  None  item
# Q22686     [2016 United States presidential election, 202...  item
# Q7154794                                                None  item
# Q57552119                                               None  item
# Q2106099                                                None  item
# Q57689     [2005 United Kingdom general election, 1997 Un...  item
# Q5585845                                                None  item
# Q4912529                                                None  item
# Q21933608                                               None  item
# Q27537235                                               None  item
# Q7520267                                                None  item
# Q39259     [2014 Turkish presidential election, 2018 Turk...  item
# Q4496      [2012 Republican Party presidential primaries,...  item
# Q509946                                                 None  item
# Q7172014                                                None  item
# Q434706    [2018 United States Senate election in Massach...  item
#
#                                                     religion
# id
# Q105756                                        [Anglicanism]
# Q1855840                                    [Roman Catholic]
# Q7817334                                                None
# Q3074013                                                None
# Q7812406                                                None
# Q977546                                            [atheism]
# Q50049                                                  None
# Q22686                                     [Presbyterianism]
# Q7154794                                                None
# Q57552119                                               None
# Q2106099                                                None
# Q57689                                                  None
# Q5585845                                                None
# Q4912529                                                None
# Q21933608                                               None
# Q27537235                                               None
# Q7520267                         [Christian Catholic Church]
# Q39259                                         [Sunni Islam]
# Q4496      [The Church of Jesus Christ of Latter-day Saints]
# Q509946                                                 None
# Q7172014                                                None
# Q434706                                          [Methodism]
